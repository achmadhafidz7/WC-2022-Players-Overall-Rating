# %% [markdown]
# ![wc_bg.jpg](attachment:wc_bg.jpg)

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd

pd.options.mode.chained_assignment = None

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### 1. Load Data

# %%
fifa23players = pd.read_csv('Fifa 23 Players Data.csv', low_memory=False)
fifa23players
# Out:
#              Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0            L. Messi        Lionel Messi       91         91        54000000
# 1          K. Benzema       Karim Benzema       91         91        64000000
# 2      R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3        K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4           K. Mbappé       Kylian Mbappé       91         95       190500000
# ...               ...                 ...      ...        ...             ...
# 18534      D. Collins      Darren Collins       47         56          110000
# 18535    Yang Dejiang        Dejiang Yang       47         57           90000
# 18536       L. Mullan         Liam Mullan       47         67          130000
# 18537    D. McCallion    Daithí McCallion       47         61          100000
# 18538        N. Rabha         Nabin Rabha       47         50           60000
#
# ...

# %% [markdown]
# ### 2. Display all the columns in the dataset

# %%
fifa23players.columns
# Out:
# Index(['Known As', 'Full Name', 'Overall', 'Potential', 'Value(in Euro)',
#        'Positions Played', 'Best Position', 'Nationality', 'Image Link', 'Age',
#        'Height(in cm)', 'Weight(in kg)', 'TotalStats', 'BaseStats',
#        'Club Name', 'Wage(in Euro)', 'Release Clause', 'Club Position',
#        'Contract Until', 'Club Jersey Number', 'Joined On', 'On Loan',
#        'Preferred Foot', 'Weak Foot Rating', 'Skill Moves',
#        'International Reputation', 'National Team Name',
#        'National Team Image Link', 'National Team Position',
#        'National Team Jersey Number', 'Attacking Work Rate',
#        'Defensive Work Rate', 'Pace Total', 'Shooting Total', 'Passing Total',
#        'Dribbling Total', 'Defending Total', 'Physicality Total', 'Crossing',
#        'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys',
#        'Dribbling', 'Curve', 'Freekick Accuracy', 'LongPassing', 'BallControl',
# ...

# %% [markdown]
# ### 3. Choose the columns needed for the analysis

# %%
columns_needed = [
    'Known As', 
    'Full Name', 
    'Age', 
    'Overall', 
    'Positions Played', 
    'Best Position', 
    'Nationality', 
    'Club Name'
]
df = pd.DataFrame(fifa23players, columns = columns_needed)
df
# Out:
#              Known As           Full Name  Age  Overall Positions Played  \
# 0            L. Messi        Lionel Messi   35       91               RW
# 1          K. Benzema       Karim Benzema   34       91            CF,ST
# 2      R. Lewandowski  Robert Lewandowski   33       91               ST
# 3        K. De Bruyne     Kevin De Bruyne   31       91           CM,CAM
# 4           K. Mbappé       Kylian Mbappé   23       91            ST,LW
# ...               ...                 ...  ...      ...              ...
# 18534      D. Collins      Darren Collins   21       47            ST,RM
# 18535    Yang Dejiang        Dejiang Yang   17       47              CDM
# 18536       L. Mullan         Liam Mullan   18       47               CM
# 18537    D. McCallion    Daithí McCallion   17       47               CB
# 18538        N. Rabha         Nabin Rabha   25       47               LB
#
#       Best Position          Nationality            Club Name
# ...

# %% [markdown]
# ### 4. Dropping null values

# %%
df.dropna(inplace=True)
df
# Out:
#              Known As           Full Name  Age  Overall Positions Played  \
# 0            L. Messi        Lionel Messi   35       91               RW
# 1          K. Benzema       Karim Benzema   34       91            CF,ST
# 2      R. Lewandowski  Robert Lewandowski   33       91               ST
# 3        K. De Bruyne     Kevin De Bruyne   31       91           CM,CAM
# 4           K. Mbappé       Kylian Mbappé   23       91            ST,LW
# ...               ...                 ...  ...      ...              ...
# 18534      D. Collins      Darren Collins   21       47            ST,RM
# 18535    Yang Dejiang        Dejiang Yang   17       47              CDM
# 18536       L. Mullan         Liam Mullan   18       47               CM
# 18537    D. McCallion    Daithí McCallion   17       47               CB
# 18538        N. Rabha         Nabin Rabha   25       47               LB
#
#       Best Position          Nationality            Club Name
# ...

# %% [markdown]
# ### 5. Filter National Teams that participate in the world cup

# %%
teams_worldcup = [
    'Qatar', 'Brazil', 'Belgium', 'France', 'Argentina', 'England', 'Spain', 'Portugal',
    'Mexico', 'Netherlands', 'Denmark', 'Germany', 'Uruguay', 'Switzerland', 'United States', 'Croatia',
    'Senegal', 'Iran', 'Japan', 'Morocco', 'Serbia', 'Poland', 'Korea Republic', 'Tunisia',
    'Cameroon', 'Canada', 'Ecuador', 'Saudi Arabia', 'Ghana', 'Wales', 'Costa Rica', 'Australia'
]

df = df[df['Nationality'].isin(teams_worldcup)]
df
# Out:
#               Known As           Full Name  Age  Overall Positions Played  \
# 0             L. Messi        Lionel Messi   35       91               RW
# 1           K. Benzema       Karim Benzema   34       91            CF,ST
# 2       R. Lewandowski  Robert Lewandowski   33       91               ST
# 3         K. De Bruyne     Kevin De Bruyne   31       91           CM,CAM
# 4            K. Mbappé       Kylian Mbappé   23       91            ST,LW
# ...                ...                 ...  ...      ...              ...
# 18486         O. Awadh        Othman Awadh   18       49           CDM,CM
# 18491        T. Maddad        Tariq Maddad   21       49               RW
# 18519       T. Giraldo       Tomas Giraldo   19       48               CM
# 18523        M. Furaih     Mohammed Furaih   22       48           CAM,RW
# 18525  J. Russell-Rowe  Jacen Russell-Rowe   19       48               ST
#
#       Best Position   Nationality              Club Name
# ...

# %% [markdown]
# #### we need to see 32 unique values in nationality, because there are 32 countries in world cup

# %%
# to see how many unique values in nationality
# We should have 32 countries

from collections import Counter

counter_object = Counter(df['Nationality'].unique())
keys = counter_object.keys()
num_values = len(keys)
num_values
# Out:
# 32

# %% [markdown]
# ### 6. Sort by Nationality

# %%
df.sort_values(by=['Nationality'], ascending=True, inplace=True)
df
# Out:
#                   Known As                Full Name  Age  Overall  \
# 0                 L. Messi             Lionel Messi   35       91
# 7853          P. Chavarría          Pablo Chavarría   34       67
# 1711             C. Guanca          Cristian Guanca   29       75
# 1708              L. Godoy           Leonardo Godoy   27       75
# 7884           F. Sbuttoni          Franco Sbuttoni   33       67
# ...                    ...                      ...  ...      ...
# 13155            J. Taylor              Jake Taylor   30       62
# 16703             M. Boyes             Morgan Boyes   21       57
# 13138  C. Lemonheigh-Evans  Connor Lemonheigh-Evans   25       62
# 1191             D. Brooks             David Brooks   24       76
# 13591            C. Gunter             Chris Gunter   32       62
#
#       Positions Played Best Position Nationality  \
# 0                   RW           CAM   Argentina
# 7853                ST            ST   Argentina
# ...

# %% [markdown]
# ### 7. Export the cleaned dataframe to .csv

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11611 entries, 0 to 13591
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Known As          11611 non-null  object
#  1   Full Name         11611 non-null  object
#  2   Age               11611 non-null  int64
#  3   Overall           11611 non-null  int64
#  4   Positions Played  11611 non-null  object
#  5   Best Position     11611 non-null  object
#  6   Nationality       11611 non-null  object
#  7   Club Name         11611 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 816.4+ KB

# %%
df.to_csv('fifa23_players_cleaned.csv', index = False)
